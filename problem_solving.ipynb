# %% [markdown]
# <a href="https://colab.research.google.com/github/ranvijay29y/sd_ranvijay_113/blob/main/problem_solving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
import math

num=25
print(math.sqrt(num))
# Out:
# 5.0

# %%
print(math.pow(2,5))
# Out:
# 32.0

# %%
print(math.factorial(5))
# Out:
# 120

# %%
print(math.ceil(4.2))
# Out:
# 5

# %%
print(math.floor(4.2))
# Out:
# 4

# %%
print(abs(-50))
# Out:
# 50

# %%
print(math.gcd(24,36))
# Out:
# 12

# %%
print(math.lcm(12,18))
# Out:
# 36

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
print(math.cos(math.radians(45)))
# Out:
# 0.7071067811865476

# %%
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log(10))
# Out:
# 2.302585092994046

# %%
import random

# %%
print(random.randint(1,10))
# Out:
# 6

# %%
print(random.random())
# Out:
# 0.9768826753971758

# %%
print(random.randrange(1,100))
# Out:
# 32

# %%
fruits=["apple","banana","mango","orange"]

print(random.choice(fruits))
# Out:
# mango

# %%
numbers =[1,2,3,4,5]
random.shuffle(numbers)
print(numbers)
# Out:
# [5, 1, 2, 4, 3]

# %%
print(random.uniform(1,10))
# Out:
# 6.7037325892124375
